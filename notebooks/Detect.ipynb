# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="9DCfJHpMAOWQLFeeemgQ")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(11)
dataset = version.download("yolov8-obb")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 45.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 117.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to License-Plate-Recognition-11 in yolov8-obb:: 100%|██████████| 20262/20262 [00:02<00:00, 6773.02it/s]

# %%
# !nvidia-smi
# Out:
# Sat May 17 07:33:30 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# Disconnect any existing mounts
from google.colab import drive
drive.flush_and_unmount()

# Restart runtime (from the menu: Runtime > Restart Runtime)

# Now remount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 119.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.137 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 42.1/235.7 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml  model="yolov8n-obb.pt" epochs=50 imgsz=640
# Out:
# ...
# 100% 6.26M/6.26M [00:00<00:00, 375MB/s]
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=obb' model. Ignoring 'task=detect' and updating to 'task=obb' to match model.
# Ultralytics 8.3.137 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
import shutil

# Change 'exp' if it's something like 'exp2', 'exp3' depending on your session
source_path = '/content/runs/obb/train/weights/best.pt'
destination_path = '/content/drive/MyDrive/License_plate_recognition_yolov8_obb/best2.pt'

shutil.copy(source_path, destination_path)
# Out:
# '/content/drive/MyDrive/License_plate_recognition_yolov8_obb/best2.pt'

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/obb/train/weights/best.pt')
metrics = model.val(data=f'{dataset.location}/data.yaml', split='train')


print(f"mAP50: {metrics.box.map50:.4f}")
print(f"mAP50-95: {metrics.box.map:.4f}")
print(f"Mean Precision: {metrics.box.mp:.4f}")
print(f"Mean Recall: {metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.3.137 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv8n-obb summary (fused): 81 layers, 3,077,414 parameters, 0 gradients, 8.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1014.0±627.2 MB/s, size: 23.2 KB)
# val: Scanning /content/License-Plate-Recognition-11/train/labels.cache... 7057 images, 5 backgrounds, 0 corrupt: 100%|██████████| 7057/7057 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 442/442 [00:53<00:00,  8.27it/s]
#                    all       7057       7357      0.992      0.987      0.994      0.886
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs/obb/val
# mAP50: 0.9941
# mAP50-95: 0.8857
# Mean Precision: 0.9922
# Mean Recall: 0.9866

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/obb/train/weights/best.pt')
metrics = model.val(data=f'{dataset.location}/data.yaml', split='val')


print(f"mAP50: {metrics.box.map50:.4f}")
print(f"mAP50-95: {metrics.box.map:.4f}")
print(f"Mean Precision: {metrics.box.mp:.4f}")
print(f"Mean Recall: {metrics.box.mr:.4f}")
# Out:
# Ultralytics 8.3.137 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLOv8n-obb summary (fused): 81 layers, 3,077,414 parameters, 0 gradients, 8.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1427.7±865.9 MB/s, size: 242.6 KB)
# val: Scanning /content/License-Plate-Recognition-11/valid/labels.cache... 2048 images, 3 backgrounds, 0 corrupt: 100%|██████████| 2048/2048 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 128/128 [00:15<00:00,  8.07it/s]
#                    all       2048       2195      0.984      0.959      0.985       0.85
# Speed: 0.2ms preprocess, 0.6ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/obb/val2
# mAP50: 0.9851
# mAP50-95: 0.8500
# Mean Precision: 0.9841
# Mean Recall: 0.9587

# %%
import shutil

shutil.make_archive('/content/train', 'zip', '/content/runs/obb/train')
from google.colab import files

files.download('/content/train.zip')

# %%
import shutil

shutil.make_archive('/content/val', 'zip', '/content/runs/obb/val')
from google.colab import files

files.download('/content/val.zip')

# %%
import shutil

shutil.make_archive('/content/val2', 'zip', '/content/runs/obb/val2')
from google.colab import files

files.download('/content/val2.zip')
